# %% [markdown]
# # Insert Sentiment

# %%
import pandas as pd
import numpy as np
import re 
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score
#from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('pertama.csv', delimiter=',')

# %%
df.head()
# Out:
#                             username      user_handle              date  \
# 0                        Michel Adam   MichelaniaAdam   10/24/2018 8:35
# 1                          PurwaRaja      RajaPurwaBU   10/24/2018 6:13
# 2                           CAK KHUM          CakKhum  10/23/2018 20:37
# 3          #RelawanProSandi Official  RelawanProSandi  10/23/2018 20:34
# 4  #RanupsPrabowoSandi Akun Official   RanupsProSandi  10/23/2018 19:47
#
#    retweets  favorites                                               text  \
# 0       132        309  Selamat bermedsos, Temans Kita promosikan keba...
# 1       101        218  SERUAN!!! HABIB RIZIEQ SHIHAB GELAR AKSI BELA ...
# 2       982       1714  Selain permintaan maaf seperti saran Gus Solah...
# 3      1124        993  Ketemu juga! Ternyata inilah Provokatornya!! M...
# 4       201        374  Gerakan # AksiBelaKalimatTauhid Dimulai # Aksi...
#
#   geological_location mentions       hashtags  tweet_id  \
# 0                 NaN      NaN            # #  1.05E+18
# 1                 NaN      NaN              #  1.05E+18
# 2                 NaN      NaN              #  1.05E+18
# 3                 NaN      NaN  # # # # # # #  1.05E+18
# 4                 NaN      NaN    # # # # # #  1.05E+18
#
#                                            permalink    tokoh sentiment
# 0  https://twitter.com/MichelaniaAdam/status/1054...  prabowo  positive
# 1  https://twitter.com/RajaPurwaBU/status/1054873...  prabowo  positive
# 2  https://twitter.com/CakKhum/status/10547285250...   jokowi  negative
# 3  https://twitter.com/RelawanProSandi/status/105...   jowowi  negative
# 4  https://twitter.com/RanupsProSandi/status/1054...  prabowo  positive

# %%
df.shape
# Out:
# (200, 13)

# %% [markdown]
# # menginputkan sentiment

# %%
df['sentimen'] = df.apply(lambda row: 'NEGATIVE', axis=1)

# %%
df['text']
# Out:
# 0      Selamat bermedsos, Temans Kita promosikan keba...
# 1      SERUAN!!! HABIB RIZIEQ SHIHAB GELAR AKSI BELA ...
# 2      Selain permintaan maaf seperti saran Gus Solah...
# 3      Ketemu juga! Ternyata inilah Provokatornya!! M...
# 4      Gerakan # AksiBelaKalimatTauhid Dimulai # Aksi...
# 5      Selalu ada trigger buat menyatukan Umat Islam,...
# 6      # AksiGarutBelaTauhid # belakalimattauhid 23.1...
# 7      Kita butuh figure dan sosok seorang yg berjiwa...
# 8      Saat Muslim Bangkit dimulai dari # AksiGarutBe...
# 9      Bukannya minta maaf malah naikin tagar beginia...
# 10     Orang ini @ GPAnsor_Satu yang paling bertanggu...
# 11     KOMEN BEBAS.. ! . KOMEN TERBAIK DAPAT HADIAH.....
# 12     Tum @ GPAnsor_Satu @ savicali @ qitmr ajarin a...
# 13     Met Milad Babe @ haikal_hassan Barokallahu Fii...
# 14     Catat dan sebarkan! Tolong di Cc-in ke Yaqut d...
# 15     Ma sya Allah ini Tanggapan @ aagym Tentang Pem...
# 16     Cuplikan Video Cak Nun Angkat Bicara Mengenai ...
# 17     Versi Ketua GP Ansor: Melihat Bendera bercecer...
# 18     Woiiii @ GPAnsor_Satu lu simak nih video dibaw...
# 19     Lautan ummat, Ulama, Kyai dan Habaib dukung Pr...
# 20     Selamat bermedsos, Temans Kita promosikan keba...
# 21     SERUAN!!! HABIB RIZIEQ SHIHAB GELAR AKSI BELA ...
# 22     Selain permintaan maaf seperti saran Gus Solah...
# 23     Ketemu juga! Ternyata inilah Provokatornya!! M...
# 24     Gerakan # AksiBelaKalimatTauhid Dimulai # Aksi...
# 25     Selalu ada trigger buat menyatukan Umat Islam,...
# 26     # AksiGarutBelaTauhid # belakalimattauhid 23.1...
# 27     Kita butuh figure dan sosok seorang yg berjiwa...
# 28     Saat Muslim Bangkit dimulai dari # AksiGarutBe...
# 29     Bukannya minta maaf malah naikin tagar beginia...
#                              ...
# 170    Cuma di Era Presiden @ jokowi Lebih dari 6 jut...
# 171    Hati2 jangan mudah terprovokasi dengan # Polit...
# 172    LSI : Pemilih Prabowo dari kalangan terpelajar...
# 173    Sertifikat Tanah Rakyat Presiden @ jokowi Ngeb...
# 174    Pemerataan dan Keadilan dalam pembangunan dari...
# 175    Pedagang Pasar Ini Marah ke @ sandiuno Merasa ...
# 176    GERAM !! Jokowi Hati hati ada Politikus yg SON...
# 177                                        Alhamdulillah
# 178    Cerdaskan Masyarakat dengan Kampanye Positif P...
# 179    Mantap Gus ,, Pengasuh Ponpes Tebu Ireng Banta...
# 180    Senang ya, jaman Pak @ jokowi pembangunan infr...
# 181    Dengerin yukk, apa kata warga... Ternyata seba...
# 182    Hai Sobat.. Tahukah Kamuh? Brand Indonesia Pal...
# 183    Apakah ini mahluk yang sengaja mengibarkan ben...
# 184    Goyang Jokowi. 2019 saatnya Ganti Presiden,dri...
# 185    Spanduk spanjang itu di buat demo kejadian yg ...
# 186    Tuh Kan , Keberhasilan Program Dana Desa Diaku...
# 187    Pak @ jokowi & @ Pak_JK, telah memberikan lebi...
# 188    Alhamdulilah bertambah lg dukungan untuk pasan...
# 189    Rakyat Indonesia Patut Bangga! Presiden Jokowi...
# 190    Cuma di Era Presiden @ jokowi Lebih dari 6 jut...
# 191    Hati2 jangan mudah terprovokasi dengan # Polit...
# 192    LSI : Pemilih Prabowo dari kalangan terpelajar...
# 193    Sertifikat Tanah Rakyat Presiden @ jokowi Ngeb...
# 194    Pemerataan dan Keadilan dalam pembangunan dari...
# 195    Pedagang Pasar Ini Marah ke @ sandiuno Merasa ...
# 196    GERAM !! Jokowi Hati hati ada Politikus yg SON...
# 197                                        Alhamdulillah
# 198    Cerdaskan Masyarakat dengan Kampanye Positif P...
# 199    Mantap Gus ,, Pengasuh Ponpes Tebu Ireng Banta...
# Name: text, Length: 200, dtype: object

# %% [markdown]
# # coba Preprocessing

# %%
import pandas
import numpy
import tqdm

tqdm.tqdm.pandas(desc="progress-bar")
from matplotlib import pyplot as plt
pandas.options.mode.chained_assignment = None


from string import punctuation
from random import shuffle
from numpy import genfromtxt
from spacy.lang.id import Indonesian

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords

# list of stopwords like articles, preposition
stop = set(stopwords.words('english'))
from string import punctuation
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>

# %% [markdown]
# # Tokenizing

# %%
nlp = Indonesian()
def isQualified(token):
    cond = True
    if (token.lemma_.lower() == 'rt'): cond = False # Qualify retweet
    if ('@' in token.lemma_.lower()): cond = False # Qualify mention
    if ('http' in token.lemma_.lower()): cond = False # Qualify url
    if ('https' in token.lemma_.lower()): cond = False # Qualify url
    if ('/t' in token.lemma_.lower()): cond = False # Qualify tag        
    if ('\n' in token.lemma_.lower()): cond = False # Qualify tag        
    if ('//' in token.lemma_.lower()): cond = False # Qualify tag  
    if ('=' in token.lemma_.lower()): cond = False # Qualify tag  
    if (' ' in token.lemma_.lower()): cond = False # Qualify tag      
    if (u'"' in token.lemma_.lower()): cond = False # Qualify tag  
    if (u's' in token.lemma_.lower()): cond = False # Qualify tag      
    if (token.text.isdigit()): cond = False    
    return cond

# %%
def tokenizer(text):
    return [token.lemma_.lower() for token in nlp(text) if not token.is_stop and not token.is_punct and isQualified(token)]

# %%
def postprocess(data):
    
    data['tokens'] = data['text'].progress_map(tokenizer)  ## progress_map is a variant of the map function plus a progress bar. Handy to monitor DataFrame creations.

    return data

data = postprocess(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-db103c86bb30> in <module>()
#       5     return data
#       6
# ----> 7 data = postprocess(df)
#
# <ipython-input-21-db103c86bb30> in postprocess(data)
#       1 def postprocess(data):
#       2
# ----> 3     data['tokens'] = data['text'].progress_map(tokenizer)  ## progress_map is a variant of the map function plus a progress bar. Handy to monitor DataFrame creations.
#       4
#       5     return data
#
# NameError: name 'tokenizer' is not defined

# %%
df
# Out:
#                               username      user_handle              date  \
# 0                          Michel Adam   MichelaniaAdam   10/24/2018 8:35
# 1                            PurwaRaja      RajaPurwaBU   10/24/2018 6:13
# 2                             CAK KHUM          CakKhum  10/23/2018 20:37
# 3            #RelawanProSandi Official  RelawanProSandi  10/23/2018 20:34
# 4    #RanupsPrabowoSandi Akun Official   RanupsProSandi  10/23/2018 19:47
# 5                                  BP™        BangPino_  10/23/2018 18:34
# 6    #RanupsPrabowoSandi Akun Official   RanupsProSandi  10/23/2018 18:30
# 7                                  BP™        BangPino_  10/23/2018 18:27
# 8            #RelawanProSandi Official  RelawanProSandi  10/23/2018 17:56
# 9                            PurwaRaja      RajaPurwaBU  10/23/2018 17:12
# 10                           PurwaRaja      RajaPurwaBU  10/23/2018 14:43
# 11                        Opposite6890     opposite6890  10/23/2018 14:41
# 12                           PurwaRaja      RajaPurwaBU  10/23/2018 13:41
# 13                                 BP™        BangPino_  10/23/2018 13:37
# 14                           PurwaRaja      RajaPurwaBU  10/23/2018 12:47
# 15                            “ZEPRET”      Neng_Zepret  10/23/2018 12:05
# 16                            “ZEPRET”      Neng_Zepret   10/23/2018 9:42
# 17                            CAK KHUM          CakKhum  10/22/2018 22:47
# 18                           💙I C E S💙         ices_tea  10/22/2018 22:26
# 19                           jundiNews        newsjundi   10/22/2018 7:17
# 20                         Michel Adam   MichelaniaAdam   10/24/2018 8:35
# 21                           PurwaRaja      RajaPurwaBU   10/24/2018 6:13
# 190       137        311  Cuma di Era Presiden @ jokowi Lebih dari 6 jut...
# 191       216        319  Hati2 jangan mudah terprovokasi dengan # Polit...
# 192       347        744  LSI : Pemilih Prabowo dari kalangan terpelajar...
# 193       100        212  Sertifikat Tanah Rakyat Presiden @ jokowi Ngeb...
# 194       322        510  Pemerataan dan Keadilan dalam pembangunan dari...
# 195       579        884  Pedagang Pasar Ini Marah ke @ sandiuno Merasa ...
# 196       382        724  GERAM !! Jokowi Hati hati ada Politikus yg SON...
# 197       250        505                                      Alhamdulillah
# 198       108        218  Cerdaskan Masyarakat dengan Kampanye Positif P...
# 199       148        273  Mantap Gus ,, Pengasuh Ponpes Tebu Ireng Banta...
#
#                                    geological_location       mentions  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# 5                                                  NaN            NaN
# 6                                                  NaN            NaN
# 7                                                  NaN              @
# 8                                                  NaN            NaN
# 9                                                  NaN            NaN
# 10                                                 NaN              @
# 11                                                 NaN            NaN
# 12                                                 NaN          @ @ @
# 13                                                 NaN              @
# 14                                                 NaN            NaN
# 15                                                 NaN              @
# 16                                                 NaN            NaN
# 17                                                 NaN            NaN
# 18                                                 NaN              @
# 19                                                 NaN            NaN
# 20                                                 NaN            NaN
# 21                                                 NaN            NaN
# 22                                                 NaN            NaN
# 23                                                 NaN            NaN
# 24                                                 NaN            NaN
# 25                                                 NaN            NaN
# 26                                                 NaN            NaN
# 27                                                 NaN              @
# 28                                                 NaN            NaN
# 29                                                 NaN            NaN
# ..                                                 ...            ...
# 170                                                NaN              @
# 171                                                NaN            NaN
# 172                                                NaN            NaN
# 173                                                NaN              @
# 174                                                NaN              @
# 175                                                NaN              @
# 176                                                NaN            NaN
# 177  Matur Suwun Bapak @ jokowi" Ibu Sujiyem. # 201...            NaN
# 178                                                NaN              @
# 179                                                NaN            NaN
# 180                                                NaN            @ @
# 181                                                NaN            NaN
# 182                                                NaN            NaN
# 183                                                NaN            NaN
# 184                                                NaN  @ @ @ @ @ @ @
# 185                                                NaN            NaN
# 186                                                NaN            NaN
# 187                                                NaN            @ @
# 188                                                NaN            NaN
# 189                                                NaN            NaN
# 190                                                NaN              @
# 191                                                NaN            NaN
# 192                                                NaN            NaN
# 193                                                NaN              @
# 194                                                NaN              @
# 195                                                NaN              @
# 196                                                NaN            NaN
# 197  Matur Suwun Bapak @ jokowi" Ibu Sujiyem. # 201...            NaN
# 198                                                NaN              @
# 199                                                NaN            NaN
#
#             hashtags  tweet_id  \
# 0                # #  1.05E+18
# 1                  #  1.05E+18
# 2                  #  1.05E+18
# 3      # # # # # # #  1.05E+18
# 4        # # # # # #  1.05E+18
# 5                  #  1.05E+18
# 6    # # # # # # # #  1.05E+18
# 7                # #  1.05E+18
# 8        # # # # # #  1.05E+18
# 9                # #  1.05E+18
# 10               # #  1.05E+18
# 11               # #  1.05E+18
# 12               # #  1.05E+18
# 13               # #  1.05E+18
# 14               # #  1.05E+18
# 15               # #  1.05E+18
# 16             # # #  1.05E+18
# 17                 #  1.05E+18
# 18               # #  1.05E+18
# 19               # #  1.05E+18
# 20               # #  1.05E+18
# 21                 #  1.05E+18
# 22                 #  1.05E+18
# 23     # # # # # # #  1.05E+18
# 24       # # # # # #  1.05E+18
# 25                 #  1.05E+18
# 26   # # # # # # # #  1.05E+18
# 27               # #  1.05E+18
# 28       # # # # # #  1.05E+18
# 29               # #  1.05E+18
# ..               ...       ...
# 170              # #  1.05E+18
# 171          # # # #  1.05E+18
# 172                #  1.05E+18
# 173              # #  1.05E+18
# 174              # #  1.05E+18
# 175              # #  1.05E+18
# 176                #  1.05E+18
# 177                @         #
# 178              # #  1.05E+18
# 179                #  1.05E+18
# 180                #  1.06E+18
# 181            # # #  1.06E+18
# 182              # #  1.06E+18
# 183              # #  1.06E+18
# 184              # #  1.06E+18
# 185                #  1.06E+18
# 186                #  1.06E+18
# 187            # # #  1.05E+18
# 188                #  1.05E+18
# 189          # # # #  1.05E+18
# 190              # #  1.05E+18
# 191          # # # #  1.05E+18
# 192                #  1.05E+18
# 193              # #  1.05E+18
# 194              # #  1.05E+18
# 195              # #  1.05E+18
# 196                #  1.05E+18
# 197                @         #
# 198              # #  1.05E+18
# 199                #  1.05E+18
#
#                                              permalink    tokoh sentiment  \
# 0    https://twitter.com/MichelaniaAdam/status/1054...  prabowo  positive
# 1    https://twitter.com/RajaPurwaBU/status/1054873...  prabowo  positive
# 2    https://twitter.com/CakKhum/status/10547285250...   jokowi  negative
# 3    https://twitter.com/RelawanProSandi/status/105...   jowowi  negative
# 4    https://twitter.com/RanupsProSandi/status/1054...  prabowo  positive
# 5    https://twitter.com/BangPino_/status/105469747...   jokowi  negative
# 6    https://twitter.com/RanupsProSandi/status/1054...   jokowi  negative
# 7    https://twitter.com/BangPino_/status/105469583...  prabowo  positive
# 8    https://twitter.com/RelawanProSandi/status/105...   jokowi  negative
# 9    https://twitter.com/RajaPurwaBU/status/1054676...   jokowi  negative
# 10   https://twitter.com/RajaPurwaBU/status/1054639...   jokowi  negative
# 11   https://twitter.com/opposite6890/status/105463...   jokowi  negative
# 12   https://twitter.com/RajaPurwaBU/status/1054623...   jokowi  negative
# 13   https://twitter.com/BangPino_/status/105462279...  prabowo  positive
# 14   https://twitter.com/RajaPurwaBU/status/1054610...   jokowi  negative
# 15   https://twitter.com/Neng_Zepret/status/1054599...   jokowi  negative
# 16   https://twitter.com/Neng_Zepret/status/1054563...   jokowi  negative
# 17   https://twitter.com/CakKhum/status/10543989535...   jokowi  negative
# 18   https://twitter.com/ices_tea/status/1054393647...   jokowi  negative
# 19   https://twitter.com/newsjundi/status/105416468...  prabowo  positive
# 20   https://twitter.com/MichelaniaAdam/status/1054...  prabowo  positive
# 21   https://twitter.com/RajaPurwaBU/status/1054873...  prabowo  positive
# 22   https://twitter.com/CakKhum/status/10547285250...   jokowi  negative
# 23   https://twitter.com/RelawanProSandi/status/105...   jokowi  negative
# 24   https://twitter.com/RanupsProSandi/status/1054...   jokowi  negative
# 25   https://twitter.com/BangPino_/status/105469747...   jokowi  negative
# 26   https://twitter.com/RanupsProSandi/status/1054...   jokowi  negative
# 27   https://twitter.com/BangPino_/status/105469583...  prabowo  positive
# 28   https://twitter.com/RelawanProSandi/status/105...   jokowi  negative
# 29   https://twitter.com/RajaPurwaBU/status/1054676...   jokowi  negative
# ..                                                 ...      ...       ...
# 170  https://twitter.com/Consheraa/status/105493827...   jokowi  positive
# 171  https://twitter.com/Dwiyana_DKM/status/1054877...  prabowo  negative
# 172  https://twitter.com/RizmaWidiono/status/105478...   jokowi  positive
# 173  https://twitter.com/Consheraa/status/105476876...   jokowi  positive
# 174  https://twitter.com/Kania_Sari27/status/105476...   jokowi  positive
# 175  https://twitter.com/RizmaWidiono/status/105475...  prabowo  negative
# 176  https://twitter.com/JajangRidwan19/status/1054...  prabowo  negative
# 177                                           1.05E+18   jokowi  positive
# 178  https://twitter.com/Consheraa/status/105471070...   jokowi  positive
# 179  https://twitter.com/JajangRidwan19/status/1054...   jokowi  positive
# 180  https://twitter.com/Dwiyana_DKM/status/1055251...   jokowi  positive
# 181  https://twitter.com/SiswantiYeni/status/105508...   jokowi  positive
# 182  https://twitter.com/Consheraa/status/105505784...   jokowi  positive
# 183  https://twitter.com/04Nakula/status/1055048933...  prabowo  negative
# 184  https://twitter.com/5Y5_one_70/status/10550389...   jokowi  positive
# 185  https://twitter.com/4Y4NKZ/status/105503264746...   jokowi  positive
# 186  https://twitter.com/JajangRidwan19/status/1054...   jokowi  positive
# 187  https://twitter.com/Dwiyana_DKM/status/1054967...   jokowi  positive
# 188  https://twitter.com/P3nj3l4j4h/status/10549571...   jokowi  positive
# 189  https://twitter.com/AdhitamaKin/status/1054939...   jokowi  positive
# 190  https://twitter.com/Consheraa/status/105493827...   jokowi  positive
# 191  https://twitter.com/Dwiyana_DKM/status/1054877...  prabowo  negative
# 192  https://twitter.com/RizmaWidiono/status/105478...   jokowi  positive
# 193  https://twitter.com/Consheraa/status/105476876...   jokowi  positive
# 194  https://twitter.com/Kania_Sari27/status/105476...   jokowi  positive
# 195  https://twitter.com/RizmaWidiono/status/105475...   jokowi  positive
# 196  https://twitter.com/JajangRidwan19/status/1054...  prabowo  negative
# 197                                           1.05E+18   jokowi  positive
# 198  https://twitter.com/Consheraa/status/105471070...   jokowi  positive
# 199  https://twitter.com/JajangRidwan19/status/1054...   jokowi  positive
#
#                                                 tokens
# 0    [kita, kebaikan2, pak, prabowo, kita, kebaikan...
# 1    [habib, rizieq, gelar, bela, tauhid, di, pic.t...
# 2    [minta, maaf, hukum, ngomong, idiot, tebang, p...
# 3    [ketemu, ternyata, provokatornya, mari, kuatka...
# 4    [gerakan, dimulai, diikuti, gema, 23.10.18, ut...
# 5    [trigger, umat, allah, jalan, bendera, tauhid,...
# 6    [belakalimattauhid, 23.10.18, gelombang, bendu...
# 7    [kita, butuh, figure, yg, jiwa, merdeka, merde...
# 8    [bangkit, 23.10.18, mari, gemakan, 4tahundiboh...
# 9    [bukannya, maaf, naikin, tagar, ini, gak, nama...
# 10   [orang, bertanggung, maaf, buka, ngajarin, men...
# 11   [komen, komen, terbaik, dapat, hadiah, hadiah,...
# 12   [tum, qitmr, ajarin, anak, buah, loe, jgn, jum...
# 13   [met, milad, babe, barokallahu, fii, umrik, ma...
# 14   [catat, tolong, cc, in, yaqut, dkk, jgn, banya...
# 15   [ma, allah, tanggapan, aagym, tentang, pembaka...
# 16   [cuplikan, video, cak, nun, angkat, bicara, me...
# 17   [ketua, gp, melihat, bendera, berceceran, dari...
# 18   [woiiii, lu, nih, video, dibawah, aja, gak, ng...
# 19   [lautan, ummat, ulama, kyai, habaib, dukung, p...
# 20   [kita, kebaikan2, pak, prabowo, kita, kebaikan...
# 21   [habib, rizieq, gelar, bela, tauhid, di, pic.t...
# 22   [minta, maaf, hukum, ngomong, idiot, tebang, p...
# 23   [ketemu, ternyata, provokatornya, mari, kuatka...
# 24   [gerakan, dimulai, diikuti, gema, 23.10.18, ut...
# 25   [trigger, umat, allah, jalan, bendera, tauhid,...
# 26   [belakalimattauhid, 23.10.18, gelombang, bendu...
# 27   [kita, butuh, figure, yg, jiwa, merdeka, merde...
# 28   [bangkit, 23.10.18, mari, gemakan, 4tahundiboh...
# 29   [bukannya, maaf, naikin, tagar, ini, gak, nama...
# ..                                                 ...
# 170  [cuma, era, jokowi, lebih, juta, tanah, bagika...
# 171  [hati2, mudah, daya, penting, kelompok, rapatk...
# 172  [pemilih, prabowo, kalang, ajar, pindah, jokow...
# 173  [tanah, rakyat, jokowi, ngebut, warga, kali, d...
# 174  [pemerataan, keadilan, bangun, merauke, era, b...
# 175  [pedagang, ini, marah, jadi, alat, politik, ka...
# 176  [geram, jokowi, hati, hati, yg, tumpah, nya, y...
# 177                                    [alhamdulillah]
# 178  [kampanye, bpk, jokowi, adu, program, adu, jok...
# 179  [mantap, tebu, ireng, bantah, dukung, prabowo,...
# 180  [ya, jaman, pak, jokowi, bangun, cepat, dinikm...
# 181  [dengerin, yukk, warga, ternyata, warga, cinta...
# 182  [hai, tahukah, kamuh, brand, paling, bernilai,...
# 183  [apakah, mahluk, kibar, bendera, hti, teriak, ...
# 184  [goyang, jokowi, ganti, dri, yg, ganti, yg, da...
# 185  [demo, jadi, yg, rencana, yg, bukan, lanjut, d...
# 186  [tuh, kan, program, dana, diakui, dunia, yg, 2...
# 187  [pak, jokowi, pak_jk, janji, kampanye, kerja, ...
# 188  [alhamdulilah, tambah, lg, dukung, jokowi, ma'...
# 189  [rakyat, patut, bangga, jokowi, menempati, uru...
# 190  [cuma, era, jokowi, lebih, juta, tanah, bagika...
# 191  [hati2, mudah, daya, penting, kelompok, rapatk...
# 192  [pemilih, prabowo, kalang, ajar, pindah, jokow...
# 193  [tanah, rakyat, jokowi, ngebut, warga, kali, d...
# 194  [pemerataan, keadilan, bangun, merauke, era, b...
# 195  [pedagang, ini, marah, jadi, alat, politik, ka...
# 196  [geram, jokowi, hati, hati, yg, tumpah, nya, y...
# 197                                    [alhamdulillah]
# 198  [kampanye, bpk, jokowi, adu, program, adu, jok...
# 199  [mantap, tebu, ireng, bantah, dukung, prabowo,...
#
# [200 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score
#from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['text'], 
                                                    df['sentiment'],
                                                    random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-22cd8cbdc55e> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(df['text'],
#       3                                                     df['sentiment'],
#       4                                                     random_state=0)
#
# NameError: name 'df' is not defined
